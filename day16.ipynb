# %%
""" 
主要是练习git 仓库的简单搭建和简单的git 命令使用。

git的三个区域，工作区-> add -> 暂存区 -> commit -> 本地仓库

好的commit message：feat:添加动量因子计算
fix:修复信号延迟错误，
refactor：重构dtype优化逻辑

.gitignore 必须包含 __pycache__/,.ipynb_checkpoints/,*.log

git log--oneline



"""
