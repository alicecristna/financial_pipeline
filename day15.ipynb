# %%
"""logging and package the code 
import logging
import logging.config

create logger
create console handler and set level
create formatter
'application code'


 logging Level
Numeric value
CRITICAL 50
ERROR 40
WARNING 30
INFO 20
DEBUG 10
NOTSET 0


Useful Handlers:

and the loggign opimization

well，you may also need to learn about the sample
and the structing

well，maybe you should also remind your mind of the memory of decorator（装饰器）

context manager的使用

以及dynamic types的合理排版


"""

# %%
"""
为什么需要学习logging和logger？

well，
1.因为之前的所有print等等，都只是一闪而过，而logging是真正将运行的信息永久写入文件内，
2.因为logging的五个等级，可以精确定位原因，
3.logging可配置，可复用，可全局统一的，配置日志文件
4.能够永久记录某些信息
5.避免使用print，控制台刷屏

well，如果有一些你觉得llm必须记住的东西，那么你应该把他们写进一个markdown文件
里面，来让它在后面的时候调用

"""

# %%
"""utils.py — 日志配置 & dtype 优化"""
import logging
from pathlib import Path

def setup_logger(name: str, log_file: str = "pipeline.log") -> logging.Logger:
    logger = logging.getLogger(name)
    logger.setLevel(logging.DEBUG)

    if logger.handlers:                    # ← 你的简洁 + 我的防重复
        return logger

    fmt = logging.Formatter(
        "%(asctime)s | %(levelname)-8s | %(message)s",
        datefmt="%Y-%m-%d %H:%M:%S"
    )

    console = logging.StreamHandler()
    console.setLevel(logging.INFO)
    console.setFormatter(fmt)

    Path(log_file).parent.mkdir(parents=True, exist_ok=True)
    fh = logging.FileHandler(log_file, encoding="utf-8")
    fh.setLevel(logging.DEBUG)
    fh.setFormatter(fmt)

    logger.addHandler(console)
    logger.addHandler(fh)
    return logger

# %%
"""统一整个项目的输出设置，不然每写一个都print那真是没完没了了，
'name':日志器的名字，一般传__name__（当前模块名)来定位日志来自哪个文件
'log_file'：日志保存路径，默认在当前路径下生成.log

well,为什么需要两个handler，
INFQ，防止刷屏，
DEBUG，文件测试。

防止重复的handler的作用，python的get logger是单刷模式，如果不加 if.logger这句，会重复叠加，一条日志打印三遍。

handler的作用，决定日志消息最终输出到哪里，控制台或者本地文件，或者服务器等等
logger负责生成，handler负责传递


在写logger的时候，首先要想清楚setLevel，然后还要想清楚Formatter是怎么样的，然后日志时间想datefmt也是十分必要的


"""
